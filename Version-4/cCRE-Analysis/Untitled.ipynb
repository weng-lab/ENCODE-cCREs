# %%
import json
import urllib
from urllib import request, parse, error
import requests
import base64
import numpy
from scipy.stats import chisquare
from scipy.stats import fisher_exact

# %%
def Query_Panther(genes):
    url = "https://www.pantherdb.org/services/oai/pantherdb/enrich/overrep?geneInputList=" \
        + genes \
        + "&organism=9606&annotDataSet=GO%3A0003674&enrichmentTestType=FISHER&correction=NONE"
    request = urllib.request.Request(url)
    response = urllib.request.urlopen(request)
    data = json.loads(response.read())
    return data
#0003674 molecular function
#0008150 biological process
#0005575 cellular component

# %%
def Retrieve_Panther_Results(inputGenes):
    goDict = {}
    genes = ""
    geneCounter = 0
    mappedGenes = 0
    for line in inputGenes:
        genes = genes + "," + line.rstrip()
        geneCounter += 1
    
        if geneCounter > 4000:
            data = Query_Panther(genes)
            for entry in data["results"]["result"]:
                if entry["term"]["label"] not in goDict:
                    goDict[entry["term"]["label"]] = 0
                goDict[entry["term"]["label"]] += entry["number_in_list"]
            mappedGenes += data["results"]["input_list"]["mapped_count"]
            genes = ""
            geneCounter = 0
            
    data = Query_Panther(genes)
    mappedGenes += data["results"]["input_list"]["mapped_count"]
    for entry in data["results"]["result"]:
        if entry["term"]["label"] not in goDict:
            goDict[entry["term"]["label"]] = 0
        goDict[entry["term"]["label"]] += entry["number_in_list"]   
    return goDict, mappedGenes

# %%
cell = "MCF-7"

# %%
dataDir = "/home/moorej3/Lab/ENCODE/Encyclopedia/V7/Registry/V7-hg38/3D-Links/PLS-comparisons/"
input1 = open(dataDir+"Panther-Common-" + cell + ".txt")
goDict1, count1 = Retrieve_Panther_Results(input1)
input1.close()

input2 = open(dataDir+"Panther-RNAPII-" + cell + ".txt")
goDict2, count2 = Retrieve_Panther_Results(input2)
input2.close()

input3 = open(dataDir+"Panther-CTCF-" + cell + ".txt")
goDict3, count3 = Retrieve_Panther_Results(input3)
input3.close()

input4 = open(dataDir+"Panther-None-" + cell + ".txt")
goDict4, count4 = Retrieve_Panther_Results(input4)
input4.close()

input5 = open(dataDir+"Panther-Background-" + cell + ".txt")
goDict5, count5 = Retrieve_Panther_Results(input5)
input5.close()

# %%
term = "transmembrane signaling receptor activity"
fraction = goDict5[term]/count5
observed = [goDict1[term], goDict2[term], goDict3[term], goDict4[term]]
expected = [count1 * fraction, count2 * fraction, count3 * fraction, count4 * fraction] 
p = chisquare(observed, expected)[1]
ratio = numpy.divide(numpy.array(observed),numpy.array(expected))
termNew = term.replace(" ","_")
padj = p * len(goDict1)
print(termNew, "\t", '{:.2e}'.format(padj), "\t", round(ratio[0],2), "\t", round(ratio[1],2), "\t", round(ratio[2],2), "\t", round(ratio[3],2))
# Out:
# transmembrane_signaling_receptor_activity 	 5.38e-08 	 1.13 	 0.6 	 2.94 	 1.72

# %%
term = "nucleic acid binding"
fraction = goDict5[term]/count5
observed = [goDict1[term], goDict2[term], goDict3[term], goDict4[term]]
expected = [count1 * fraction, count2 * fraction, count3 * fraction, count4 * fraction] 
p = chisquare(observed, expected)[1]
ratio = numpy.divide(numpy.array(observed),numpy.array(expected))
termNew = term.replace(" ","_")
padj = p * len(goDict1)
print(termNew, "\t", '{:.2e}'.format(padj), "\t", round(ratio[0],2), "\t", round(ratio[1],2), "\t", round(ratio[2],2), "\t", round(ratio[3],2))
# Out:
# nucleic_acid_binding 	 9.98e-15 	 0.95 	 1.19 	 0.59 	 0.88

# %%
#outputFile=open("test-MCF.txt", "w+")
for term in goDict5:
    fraction = goDict5[term]/count5
    observed = [goDict1[term], goDict2[term], goDict3[term], goDict4[term]]
    expected = [count1 * fraction, count2 * fraction, count3 * fraction, count4 * fraction] 
    p = chisquare(observed, expected)[1]
    ratio = numpy.divide(numpy.array(observed),numpy.array(expected))
    termNew = term.replace(" ","_")
    if p < correctedP and goDict5[term] >= 25:
        print(termNew, "\t", '{:.2e}'.format(p), "\t", round(ratio[0],2), "\t", round(ratio[1],2), "\t", round(ratio[2],2), "\t", round(ratio[3],2))
#outputFile.close()
# Out:
# organic_cyclic_compound_binding 	 1.07e-09 	 0.98 	 1.11 	 0.74 	 0.93
# heterocyclic_compound_binding 	 1.09e-10 	 0.99 	 1.11 	 0.71 	 0.92
# G_protein-coupled_receptor_activity 	 6.79e-06 	 0.72 	 0.7 	 1.85 	 1.52
# RNA_binding 	 5.79e-19 	 1.01 	 1.26 	 0.48 	 0.72
# nucleic_acid_binding 	 1.97e-18 	 0.95 	 1.19 	 0.59 	 0.88
# transmembrane_signaling_receptor_activity 	 2.76e-12 	 0.75 	 0.68 	 1.85 	 1.47
# molecular_transducer_activity 	 8.94e-13 	 0.82 	 0.72 	 1.9 	 1.37
# signaling_receptor_activity 	 8.94e-13 	 0.82 	 0.72 	 1.9 	 1.37
# catalytic_activity,_acting_on_a_nucleic_acid 	 5.17e-06 	 1.14 	 1.09 	 0.18 	 0.84
# cadherin_binding 	 1.80e-06 	 1.13 	 1.35 	 0.62 	 0.61
# signaling_receptor_regulator_activity 	 1.03e-11 	 1.34 	 0.54 	 2.78 	 1.09
# signaling_receptor_activator_activity 	 1.38e-11 	 1.33 	 0.53 	 2.85 	 1.04
# receptor_ligand_activity 	 3.30e-12 	 1.35 	 0.51 	 2.94 	 1.01
# DNA_binding 	 2.34e-07 	 0.89 	 1.15 	 0.67 	 0.99
# structural_constituent_of_ribosome 	 7.31e-07 	 0.83 	 1.54 	 0.63 	 0.43
# voltage-gated_monoatomic_cation_channel_activity 	 3.49e-19 	 0.51 	 0.22 	 4.83 	 1.72
# monoatomic_ion_gated_channel_activity 	 9.14e-19 	 0.46 	 0.55 	 3.58 	 1.52
# gated_channel_activity 	 4.29e-18 	 0.48 	 0.56 	 3.53 	 1.5
# channel_activity 	 6.65e-16 	 0.59 	 0.71 	 2.87 	 1.37
# passive_transmembrane_transporter_activity 	 5.39e-16 	 0.58 	 0.71 	 2.86 	 1.38
# monoatomic_ion_channel_activity 	 4.73e-13 	 0.59 	 0.7 	 2.74 	 1.39
# ligand-gated_monoatomic_ion_channel_activity 	 4.12e-09 	 0.22 	 0.63 	 4.03 	 1.49
# monoatomic_cation_channel_activity 	 6.02e-13 	 0.59 	 0.66 	 3.11 	 1.35
# signaling_receptor_binding
# <ipython-input-262-d5acc506d369>:7: RuntimeWarning: invalid value encountered in true_divide
#   ratio = numpy.divide(numpy.array(observed),numpy.array(expected))
#  	 1.24e-06 	 1.15 	 0.79 	 1.37 	 1.16
# ligand-gated_channel_activity 	 8.40e-09 	 0.22 	 0.67 	 3.95 	 1.46
# voltage-gated_potassium_channel_activity 	 1.34e-21 	 0.5 	 0.32 	 6.71 	 1.29
# voltage-gated_monoatomic_ion_channel_activity 	 1.25e-18 	 0.46 	 0.44 	 4.34 	 1.56
# voltage-gated_channel_activity 	 3.33e-18 	 0.5 	 0.43 	 4.29 	 1.55
# potassium_channel_regulator_activity 	 7.23e-06 	 0.83 	 1.17 	 4.97 	 0.72
# potassium_channel_activity 	 2.28e-19 	 0.47 	 0.4 	 5.8 	 1.35
# ligand-gated_monoatomic_cation_channel_activity 	 1.55e-08 	 0.17 	 0.68 	 4.29 	 1.35
# inorganic_cation_transmembrane_transporter_activity 	 4.86e-11 	 0.88 	 0.69 	 2.46 	 1.17
# growth_factor_activity 	 6.94e-06 	 1.68 	 0.52 	 2.46 	 0.86
# salt_transmembrane_transporter_activity 	 3.48e-09 	 0.86 	 0.69 	 2.25 	 1.24
# transmembrane_transporter_activity 	 1.05e-07 	 0.96 	 0.79 	 1.8 	 1.11
# monoatomic_ion_transmembrane_transporter_activity 	 2.26e-09 	 0.86 	 0.75 	 2.15 	 1.18
# metal_ion_transmembrane_transporter_activity 	 3.06e-11 	 0.8 	 0.61 	 2.51 	 1.33
# monoatomic_cation_transmembrane_transporter_activity 	 1.29e-09 	 0.87 	 0.71 	 2.3 	 1.17
# inorganic_molecular_entity_transmembrane_transporter_activity 	 1.33e-09 	 0.89 	 0.73 	 2.24 	 1.15
# transporter_activity 	 5.12e-08 	 0.95 	 0.8 	 1.74 	 1.12
# potassium_ion_transmembrane_transporter_activity 	 1.22e-14 	 0.63 	 0.47 	 4.36 	 1.43

# %%
for term in goDict5:
    observed = [goDict1[term], count1-goDict1[term]]
    expected = [goDict2[term], count2-goDict2[term]]
    p = fisher_exact([observed,expected])[1]
    ratio = numpy.divide(numpy.array(observed),numpy.array(expected))
    termNew = term.replace(" ","_")
    if p < correctedP and goDict5[term] >= 25:
        print(termNew, "\t", '{:.2e}'.format(p), "\t", round(ratio[0],2), "\t", round(goDict1[term]/count1,2), "\t", round(goDict2[term]/count2,2))
# Out:
# <ipython-input-211-3572270caaee>:5: RuntimeWarning: invalid value encountered in true_divide
#   ratio = numpy.divide(numpy.array(observed),numpy.array(expected))
# regulation_of_nucleobase-containing_compound_metabolic_process 	 3.02e-07 	 0.53 	 0.23 	 0.28
# regulation_of_gene_expression 	 8.84e-07 	 0.54 	 0.26 	 0.31
# regulation_of_RNA_metabolic_process 	 5.02e-07 	 0.52 	 0.21 	 0.26
# regulation_of_DNA-templated_transcription 	 1.38e-06 	 0.52 	 0.19 	 0.23
# regulation_of_RNA_biosynthetic_process 	 2.22e-06 	 0.53 	 0.19 	 0.23
# <ipython-input-211-3572270caaee>:5: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = numpy.divide(numpy.array(observed),numpy.array(expected))

# %%
for term in goDict5:
    observed = [goDict3[term], count3-goDict3[term]]
    expected = [goDict5[term], count5-goDict5[term]]
    p = fisher_exact([observed,expected])[1]
    termNew = term.replace(" ","_")
    if p < correctedP and goDict5[term] >= 25:
        print(termNew, "\t", '{:.2e}'.format(p), "\t", round(goDict3[term]/count3*100,2), "\t", round(goDict5[term]/count5*100,2))
# Out:
# organic_cyclic_compound_binding 	 1.87e-07 	 27.93 	 37.84
# heterocyclic_compound_binding 	 8.09e-09 	 26.58 	 37.47
# RNA_binding 	 3.51e-07 	 5.56 	 11.54
# nucleic_acid_binding 	 1.25e-10 	 15.02 	 25.62
# catalytic_activity,_acting_on_a_nucleic_acid 	 2.45e-07 	 0.75 	 4.25
# signaling_receptor_regulator_activity 	 3.57e-06 	 4.35 	 1.57
# catalytic_activity,_acting_on_RNA 	 9.89e-06 	 0.3 	 2.68
# signaling_receptor_activator_activity 	 3.51e-06 	 4.2 	 1.48
# receptor_ligand_activity 	 2.08e-06 	 4.2 	 1.43
# voltage-gated_monoatomic_cation_channel_activity 	 1.77e-07 	 2.85 	 0.59
# monoatomic_ion_gated_channel_activity 	 3.62e-08 	 4.35 	 1.22
# gated_channel_activity 	 4.76e-08 	 4.35 	 1.23
# channel_activity 	 5.27e-08 	 5.71 	 1.99
# passive_transmembrane_transporter_activity 	 5.85e-08 	 5.71 	 2.0
# monoatomic_ion_channel_activity 	 1.49e-06 	 4.8 	 1.75
# monoatomic_cation_channel_activity 	 7.60e-07 	 4.2 	 1.35
# voltage-gated_potassium_channel_activity 	 6.01e-09 	 2.7 	 0.4
# voltage-gated_monoatomic_ion_channel_activity 	 4.92e-08 	 3.45 	 0.8
# voltage-gated_channel_activity 	 5.85e-08 	 3.45 	 0.81
# potassium_channel_activity 	 1.59e-08 	 2.85 	 0.49
# inorganic_cation_transmembrane_transporter_activity 	 5.47e-07 	 6.31 	 2.56
# monoatomic_ion_transmembrane_transporter_activity 	 4.71e-06 	 6.91 	 3.21
# metal_ion_transmembrane_transporter_activity 	 8.29e-06 	 4.8 	 1.91
# monoatomic_cation_transmembrane_transporter_activity 	 3.49e-06 	 6.16 	 2.68
# inorganic_molecular_entity_transmembrane_transporter_activity 	 2.28e-06 	 6.76 	 3.02
# potassium_ion_transmembrane_transporter_activity 	 3.43e-07 	 3.0 	 0.69

# %%
dataDir = "/home/moorej3/Lab/ENCODE/Encyclopedia/V7/Registry/V7-hg38/Cell-Type-Specific/"
input1 = open(dataDir+"low-low.genes")
goDict1, count1 = Retrieve_Panther_Results(input1)
input1.close()

input2 = open(dataDir+"low-high.genes")
goDict2, count2 = Retrieve_Panther_Results(input2)
input2.close()

# %%
for term in goDict1:
    observed = [goDict2[term], count2-goDict2[term]]
    expected = [goDict1[term], count1-goDict1[term]]
    p = fisher_exact([observed,expected])[1]
    termNew = term.replace(" ","_")
    padj = p * len(goDict1)
    if goDict5[term] >= 25:
        print(termNew, "\t", '{:.2e}'.format(padj), "\t", round(goDict1[term]/count2*100,2), "\t", round(goDict1[term]/count1*100,2))
# Out:
# RNA_binding 	 2.82e+03 	 4.4 	 2.69
# cytoskeletal_protein_binding 	 2.84e+03 	 16.69 	 10.2
# UNCLASSIFIED 	 1.20e+03 	 10.02 	 6.12
# molecular_function 	 1.20e+03 	 153.57 	 93.88
# binding 	 2.13e+03 	 142.94 	 87.38
# protein_binding 	 2.82e+03 	 126.86 	 77.55
# actin_binding 	 4.12e+03 	 7.74 	 4.73
# catalytic_activity,_acting_on_a_nucleic_acid 	 5.06e+03 	 1.37 	 0.83
# ion_binding 	 1.65e+03 	 59.18 	 36.18
# kinesin_binding 	 4.81e+02 	 1.82 	 1.11
# tubulin_binding 	 3.53e+03 	 6.37 	 3.9
# gated_channel_activity 	 3.97e+03 	 5.77 	 3.53
# RNA_polymerase_II_cis-regulatory_region_sequence-specific_DNA_binding 	 8.15e+01 	 14.72 	 9.0
# monoatomic_ion_gated_channel_activity 	 4.51e+03 	 5.61 	 3.43
# cis-regulatory_region_sequence-specific_DNA_binding 	 6.48e+01 	 14.87 	 9.09
# monoatomic_cation_channel_activity 	 1.99e+03 	 5.61 	 3.43
# channel_activity 	 1.36e+03 	 7.59 	 4.64
# passive_transmembrane_transporter_activity 	 1.36e+03 	 7.59 	 4.64
# DNA-binding_transcription_factor_activity 	 1.58e+02 	 16.69 	 10.2
# potassium_ion_transmembrane_transporter_activity 	 2.37e+03 	 3.34 	 2.04
# metal_ion_binding 	 1.69e+03 	 42.64 	 26.07
# DNA-binding_transcription_factor_activity,_RNA_polymerase_II-specific 	 2.80e+02 	 16.08 	 9.83
# monoatomic_ion_channel_activity 	 1.84e+03 	 6.68 	 4.08
# RNA_polymerase_II_transcription_regulatory_region_sequence-specific_DNA_binding 	 1.45e+02 	 16.24 	 9.93
# protein_kinase_activity 	 2.43e+03 	 8.04 	 4.92
# cation_binding 	 2.34e+03 	 42.94 	 26.25
# calcium_ion_binding 	 3.43e+03 	 9.56 	 5.84
# protein_domain_specific_binding 	 3.75e+03 	 8.95 	 5.47
# transmembrane_transporter_binding 	 2.17e+03 	 2.88 	 1.76
# protein_kinase_binding 	 1.93e+03 	 9.41 	 5.75
# phosphatidylinositol-4,5-bisphosphate_binding 	 6.53e+02 	 2.12 	 1.3
# kinase_binding 	 3.04e+03 	 10.17 	 6.22
# transcription_cis-regulatory_region_binding 	 1.00e+02 	 16.84 	 10.3
# structural_constituent_of_ribosome 	 1.92e+03 	 0.0 	 0.0
# transcription_regulatory_region_nucleic_acid_binding 	 1.00e+02 	 16.84 	 10.3
# phosphatidylinositol_bisphosphate_binding 	 2.83e+02 	 2.43 	 1.48
# channel_regulator_activity 	 5.06e+03 	 3.03 	 1.86
# sequence-specific_double-stranded_DNA_binding 	 8.55e+01 	 17.3 	 10.58
# G_protein-coupled_receptor_activity 	 1.75e+03 	 3.64 	 2.23
# microtubule_binding 	 5.06e+03 	 4.4 	 2.69
# phospholipid_binding 	 9.21e+02 	 6.68 	 4.08
# kinase_activity 	 2.61e+03 	 9.56 	 5.84
# anion_binding 	 3.43e+03 	 25.19 	 15.4
# voltage-gated_channel_activity 	 5.06e+03 	 3.49 	 2.13
# DNA-binding_transcription_activator_activity,_RNA_polymerase_II-specific 	 6.91e+02 	 6.53 	 3.99
# amyloid-beta_binding 	 3.24e+03 	 1.97 	 1.21
# catalytic_activity,_acting_on_RNA 	 5.06e+03 	 1.06 	 0.65
# nucleic_acid_binding 	 6.17e+02 	 25.34 	 15.49
# mRNA_binding 	 3.73e+03 	 0.76 	 0.46
# phosphotransferase_activity,_alcohol_group_as_acceptor 	 3.30e+03 	 8.65 	 5.29
# DNA-binding_transcription_activator_activity 	 6.91e+02 	 6.53 	 3.99
# salt_transmembrane_transporter_activity 	 3.20e+03 	 7.59 	 4.64
# ion_channel_regulator_activity 	 4.30e+03 	 2.73 	 1.67
# double-stranded_DNA_binding 	 9.41e+01 	 17.75 	 10.85
# protein_tyrosine_kinase_activity 	 2.06e+03 	 2.73 	 1.67
# metal_ion_transmembrane_transporter_activity 	 5.06e+03 	 6.07 	 3.71
# ephrin_receptor_binding 	 3.80e+03 	 1.06 	 0.65
# sequence-specific_DNA_binding 	 1.84e+02 	 17.75 	 10.85
# purine_ribonucleoside_triphosphate_binding 	 2.71e+03 	 19.27 	 11.78
# potassium_channel_activity 	 2.64e+03 	 2.43 	 1.48
# monoatomic_cation_transmembrane_transporter_activity 	 2.36e+03 	 7.59 	 4.64
# monoatomic_ion_transmembrane_transporter_activity 	 2.53e+03 	 8.8 	 5.38
# protein_kinase_C_binding 	 1.13e+03 	 1.37 	 0.83
# GTPase_regulator_activity 	 5.08e+02 	 6.53 	 3.99
# voltage-gated_monoatomic_ion_channel_activity 	 5.06e+03 	 3.34 	 2.04
# nucleoside-triphosphatase_regulator_activity 	 5.08e+02 	 6.53 	 3.99
# potassium_channel_regulator_activity 	 1.13e+03 	 1.37 	 0.83
# transferase_activity,_transferring_phosphorus-containing_groups 	 1.29e+03 	 10.77 	 6.59
# channel_inhibitor_activity 	 5.06e+03 	 1.21 	 0.74
# purine_ribonucleotide_binding 	 3.26e+03 	 19.73 	 12.06
# transcription_regulator_activity 	 8.12e+01 	 19.73 	 12.06
# molecular_function_regulator_activity 	 1.30e+03 	 22.0 	 13.45
# PDZ_domain_binding 	 5.06e+03 	 1.82 	 1.11
# actin_filament_binding 	 5.06e+03 	 3.34 	 2.04
# extracellular_matrix_binding 	 1.13e+03 	 1.37 	 0.83
# ribonucleotide_binding 	 3.26e+03 	 19.73 	 12.06
# purine_nucleotide_binding 	 3.86e+03 	 20.49 	 12.52
# inorganic_molecular_entity_transmembrane_transporter_activity 	 2.46e+03 	 8.19 	 5.01
# inorganic_cation_transmembrane_transporter_activity 	 3.58e+03 	 6.98 	 4.27
# collagen_binding 	 4.07e+03 	 1.52 	 0.93
# lipid_binding 	 1.96e+03 	 9.71 	 5.94
# ligand-gated_monoatomic_cation_channel_activity 	 4.16e+03 	 2.12 	 1.3
# ligand-gated_monoatomic_ion_channel_activity 	 5.06e+03 	 2.58 	 1.58
# ligand-gated_channel_activity 	 5.06e+03 	 2.58 	 1.58
# microtubule_motor_activity 	 4.02e+03 	 1.52 	 0.93
# catalytic_activity,_acting_on_DNA 	 3.32e+03 	 0.61 	 0.37
# voltage-gated_monoatomic_cation_channel_activity 	 5.06e+03 	 2.58 	 1.58
# protein_serine_kinase_activity 	 1.80e+03 	 4.86 	 2.97
# cytoskeletal_motor_activity 	 4.16e+03 	 2.12 	 1.3
# transcription_coregulator_binding 	 1.13e+03 	 2.12 	 1.3
# clathrin_binding 	 1.98e+03 	 1.52 	 0.93
# phosphatidylinositol_phosphate_binding 	 1.24e+02 	 2.88 	 1.76
# ion_channel_inhibitor_activity 	 5.06e+03 	 1.06 	 0.65
# enzyme_regulator_activity 	 1.98e+03 	 14.11 	 8.63
# ATP_binding 	 1.72e+03 	 15.48 	 9.46
# SH2_domain_binding 	 3.80e+03 	 1.06 	 0.65
# protein_serine/threonine_kinase_activity 	 1.99e+03 	 5.46 	 3.34
# carbohydrate_derivative_binding 	 3.63e+03 	 22.46 	 13.73
# nuclease_activity 	 5.06e+03 	 0.46 	 0.28
# enzyme_binding 	 2.58e+03 	 20.79 	 12.71
# growth_factor_binding 	 2.19e+03 	 2.28 	 1.39
# voltage-gated_potassium_channel_activity 	 3.12e+03 	 1.82 	 1.11
# ribonucleoprotein_complex_binding 	 5.06e+03 	 0.3 	 0.19
# nucleotide_binding 	 4.17e+03 	 21.24 	 12.99
# adenyl_ribonucleotide_binding 	 1.98e+03 	 15.78 	 9.65
# transcription_factor_binding 	 1.19e+02 	 7.13 	 4.36
# nucleoside_phosphate_binding 	 4.17e+03 	 21.24 	 12.99
# catalytic_activity,_acting_on_a_tRNA 	 5.06e+03 	 0.15 	 0.09
# phosphatidylinositol_binding 	 1.48e+03 	 3.79 	 2.32
# transcription_coactivator_binding 	 2.51e+03 	 1.06 	 0.65
# calcium_channel_activity 	 5.06e+03 	 2.12 	 1.3
# guanyl-nucleotide_exchange_factor_activity 	 7.47e+01 	 3.19 	 1.95
# adenyl_nucleotide_binding 	 2.56e+03 	 16.54 	 10.11
# protein-containing_complex_binding 	 2.10e+03 	 17.6 	 10.76
# phosphatidylserine_binding 	 5.06e+03 	 1.21 	 0.74
# transmembrane_receptor_protein_tyrosine_kinase_activity 	 3.97e+03 	 1.21 	 0.74
# ATP-dependent_activity,_acting_on_DNA 	 5.06e+03 	 0.15 	 0.09
# transmembrane_transporter_activity 	 3.52e+03 	 11.68 	 7.14
# enzyme_activator_activity 	 5.06e+03 	 7.13 	 4.36
# nuclear_estrogen_receptor_binding 	 1.33e+03 	 0.91 	 0.56
# calcium-dependent_phospholipid_binding 	 2.51e+03 	 1.06 	 0.65
# scaffold_protein_binding 	 3.01e+03 	 1.21 	 0.74
# catalytic_activity,_acting_on_a_protein 	 3.90e+03 	 22.0 	 13.45
# phosphoric_diester_hydrolase_activity 	 5.06e+03 	 1.52 	 0.93
# beta-catenin_binding 	 3.18e+03 	 1.52 	 0.93
# phosphoric_ester_hydrolase_activity 	 2.82e+03 	 4.4 	 2.69
# coreceptor_activity 	 3.80e+03 	 1.06 	 0.65
# signaling_receptor_binding 	 1.08e+03 	 14.87 	 9.09
# DNA-binding_transcription_repressor_activity 	 5.06e+03 	 4.1 	 2.5
# non-membrane_spanning_protein_tyrosine_kinase_activity 	 1.33e+03 	 0.91 	 0.56
# calcium_ion_transmembrane_transporter_activity 	 5.06e+03 	 2.12 	 1.3
# GTPase_activator_activity 	 3.68e+03 	 3.49 	 2.13
# signaling_adaptor_activity 	 1.98e+03 	 1.52 	 0.93
# molecular_adaptor_activity 	 3.01e+03 	 6.22 	 3.8
# phosphoprotein_phosphatase_activity 	 3.52e+03 	 2.43 	 1.48
# ribosome_binding 	 5.06e+03 	 0.15 	 0.09
# transmembrane_receptor_protein_kinase_activity 	 3.11e+03 	 1.37 	 0.83
# phosphotyrosine_residue_binding 	 5.06e+03 	 0.91 	 0.56
# DNA-binding_transcription_repressor_activity,_RNA_polymerase_II-specific 	 4.42e+03 	 3.95 	 2.41
# GTPase_activity 	 3.81e+03 	 3.95 	 2.41
# oxidoreductase_activity 	 1.83e+03 	 3.95 	 2.41
# SNARE_binding 	 5.06e+03 	 1.67 	 1.02
# phospholipase_activity 	 5.06e+03 	 1.67 	 1.02
# damaged_DNA_binding 	 5.06e+03 	 0.0 	 0.0
# cargo_receptor_activity 	 2.79e+03 	 1.37 	 0.83
# structural_molecule_activity 	 6.24e+02 	 4.4 	 2.69
# growth_factor_receptor_binding 	 5.06e+03 	 1.97 	 1.21
# protein_self-association 	 1.70e+03 	 1.21 	 0.74
# protein_phosphatase_binding 	 2.37e+03 	 1.97 	 1.21
# myosin_binding 	 3.01e+03 	 1.21 	 0.74
# small_molecule_binding 	 3.68e+03 	 23.67 	 14.47
# transporter_activity 	 4.68e+03 	 12.14 	 7.42
# identical_protein_binding 	 4.46e+03 	 20.18 	 12.34
# helicase_activity 	 5.06e+03 	 0.46 	 0.28
# RNA_nuclease_activity 	 5.06e+03 	 0.3 	 0.19
# endonuclease_activity 	 5.06e+03 	 0.3 	 0.19
# phosphatidylinositol-3,4,5-trisphosphate_binding 	 8.27e+02 	 0.76 	 0.46
# protein_serine/threonine_phosphatase_activity 	 4.07e+03 	 1.52 	 0.93
# structural_constituent_of_chromatin 	 5.06e+03 	 0.0 	 0.0
# exonuclease_activity,_active_with_either_ribo-_or_deoxyribonucleic_acids_and_producing_5'-phosphomonoesters 	 5.06e+03 	 0.0 	 0.0
# 2-oxoglutarate-dependent_dioxygenase_activity 	 7.27e+02 	 0.0 	 0.0
# protein_dimerization_activity 	 3.44e+03 	 10.47 	 6.4
# RNA_methyltransferase_activity 	 5.06e+03 	 0.0 	 0.0
# rRNA_binding 	 5.06e+03 	 0.0 	 0.0
# protein_folding_chaperone 	 5.06e+03 	 0.0 	 0.0
# DNA-binding_transcription_factor_binding 	 3.20e+02 	 5.31 	 3.25
# tau_protein_binding 	 5.06e+03 	 0.76 	 0.46
# cell_adhesion_mediator_activity 	 5.06e+03 	 1.06 	 0.65
# protein-macromolecule_adaptor_activity 	 3.24e+03 	 4.4 	 2.69
# ubiquitin_protein_ligase_binding 	 2.13e+03 	 3.49 	 2.13
# transferase_activity,_transferring_one-carbon_groups 	 5.06e+03 	 0.91 	 0.56
# inorganic_anion_transmembrane_transporter_activity 	 1.60e+03 	 1.97 	 1.21
# cytokine_activity 	 1.96e+03 	 0.91 	 0.56
# syntaxin_binding 	 3.91e+03 	 1.06 	 0.65
# cell_adhesion_molecule_binding 	 4.52e+03 	 5.77 	 3.53
# ubiquitin-like_protein_ligase_binding 	 2.64e+03 	 3.64 	 2.23
# histone_modifying_activity 	 2.11e+03 	 0.76 	 0.46
# cadherin_binding 	 3.07e+03 	 3.64 	 2.23
# phosphatidylinositol-3-phosphate_binding 	 8.27e+02 	 0.76 	 0.46
# endopeptidase_inhibitor_activity 	 3.32e+03 	 0.61 	 0.37
# general_transcription_initiation_factor_activity 	 5.06e+03 	 0.0 	 0.0
# 3'-5'_exonuclease_activity 	 5.06e+03 	 0.0 	 0.0
# lipid_transfer_activity 	 1.04e+02 	 0.0 	 0.0
# calmodulin_binding 	 3.82e+02 	 2.43 	 1.48
# oxidoreductase_activity,_acting_on_NAD(P)H,_quinone_or_similar_compound_as_acceptor 	 5.06e+03 	 0.0 	 0.0
# polyubiquitin_modification-dependent_protein_binding 	 1.92e+03 	 0.0 	 0.0
# lipase_activity 	 2.52e+03 	 1.67 	 1.02
# DNA_helicase_activity 	 5.06e+03 	 0.0 	 0.0
# peptidase_activator_activity 	 5.06e+03 	 0.91 	 0.56
# electron_transfer_activity 	 5.06e+03 	 0.3 	 0.19
# protein_phosphorylated_amino_acid_binding 	 5.06e+03 	 0.91 	 0.56
# modified_amino_acid_binding 	 5.06e+03 	 1.21 	 0.74
# E-box_binding 	 4.49e+02 	 0.91 	 0.56
# myosin_phosphatase_activity 	 5.06e+03 	 1.21 	 0.74
# ATPase_binding 	 5.06e+03 	 1.21 	 0.74
# chloride_transmembrane_transporter_activity 	 1.98e+03 	 1.52 	 0.93
# phosphatase_binding 	 5.06e+03 	 2.28 	 1.39
# gamma-tubulin_binding 	 5.06e+03 	 0.61 	 0.37
# guanyl_nucleotide_binding 	 1.55e+03 	 4.25 	 2.6
# guanyl_ribonucleotide_binding 	 1.55e+03 	 4.25 	 2.6
# S-adenosylmethionine-dependent_methyltransferase_activity 	 5.06e+03 	 0.61 	 0.37
# methyltransferase_activity 	 5.06e+03 	 0.91 	 0.56
# phosphoprotein_binding 	 1.59e+03 	 1.21 	 0.74
# oxidoreductase_activity,_acting_on_CH-OH_group_of_donors 	 3.44e+03 	 0.46 	 0.28
# NADH_dehydrogenase_activity 	 5.06e+03 	 0.0 	 0.0
# NAD(P)H_dehydrogenase_(quinone)_activity 	 5.06e+03 	 0.0 	 0.0
# phosphatase_activity 	 3.03e+03 	 3.03 	 1.86
# endopeptidase_regulator_activity 	 5.06e+03 	 0.76 	 0.46
# serine-type_endopeptidase_inhibitor_activity 	 2.67e+03 	 0.3 	 0.19
# snRNA_binding 	 5.06e+03 	 0.0 	 0.0
# nuclear_receptor_binding 	 7.53e+02 	 1.67 	 1.02
# mRNA_3'-UTR_binding 	 2.67e+03 	 0.3 	 0.19
# glutamate_receptor_binding 	 1.17e+03 	 0.76 	 0.46
# molecular_function_activator_activity 	 2.55e+03 	 11.23 	 6.86
# monosaccharide_binding 	 7.04e+01 	 0.15 	 0.09
# calcium_channel_regulator_activity 	 1.77e+03 	 0.76 	 0.46
# exonuclease_activity 	 5.06e+03 	 0.15 	 0.09
# histone_binding 	 5.06e+03 	 1.21 	 0.74
# SMAD_binding 	 1.38e+03 	 1.06 	 0.65
# mitogen-activated_protein_kinase_binding 	 5.06e+03 	 0.46 	 0.28
# ATP_hydrolysis_activity 	 3.43e+03 	 2.12 	 1.3
# GTP_binding 	 1.83e+03 	 3.95 	 2.41
# chloride_channel_activity 	 2.51e+03 	 1.06 	 0.65
# signaling_receptor_complex_adaptor_activity 	 3.62e+03 	 0.76 	 0.46
# cell-cell_adhesion_mediator_activity 	 3.73e+03 	 0.76 	 0.46
# ubiquitin-like_protein_transferase_activity 	 1.45e+03 	 2.73 	 1.67
# calcium-dependent_protein_binding 	 2.51e+03 	 1.06 	 0.65
# structural_constituent_of_cytoskeleton 	 2.32e+03 	 1.37 	 0.83
# aminoacyltransferase_activity 	 1.92e+03 	 2.88 	 1.76
# nuclear_receptor_activity 	 5.06e+03 	 0.76 	 0.46
# ligand-activated_transcription_factor_activity 	 5.06e+03 	 0.76 	 0.46
# oxidoreductase_activity,_acting_on_the_CH-OH_group_of_donors,_NAD_or_NADP_as_acceptor 	 3.44e+03 	 0.46 	 0.28
# heat_shock_protein_binding 	 5.06e+03 	 0.46 	 0.28
# modification-dependent_protein_binding 	 3.73e+03 	 0.76 	 0.46
# SH3_domain_binding 	 2.41e+03 	 1.52 	 0.93
# ubiquitin-protein_transferase_activity 	 1.81e+03 	 2.58 	 1.58
# hormone_binding 	 3.80e+03 	 1.06 	 0.65
# molecular_carrier_activity 	 3.22e+03 	 0.3 	 0.19
# lyase_activity 	 8.52e+02 	 0.91 	 0.56
# protein_heterodimerization_activity 	 4.35e+03 	 3.19 	 1.95
# protein_tyrosine_phosphatase_activity 	 3.01e+03 	 1.21 	 0.74
# vitamin_binding 	 1.58e+03 	 0.61 	 0.37
# peptide_binding 	 5.06e+03 	 3.34 	 2.04
# 3'-5'-RNA_exonuclease_activity 	 5.06e+03 	 0.0 	 0.0
# ADP_binding 	 1.92e+03 	 0.0 	 0.0
# ATP-dependent_chromatin_remodeler_activity 	 5.06e+03 	 0.0 	 0.0
# pre-mRNA_binding 	 1.92e+03 	 0.0 	 0.0
# ubiquitin-like_protein_conjugating_enzyme_binding 	 7.27e+02 	 0.0 	 0.0
# oxidoreduction-driven_active_transmembrane_transporter_activity 	 5.06e+03 	 0.15 	 0.09
# protein_transporter_activity 	 1.92e+03 	 0.0 	 0.0
# RNA_exonuclease_activity,_producing_5'-phosphomonoesters 	 5.06e+03 	 0.0 	 0.0
# nucleosomal_DNA_binding 	 5.06e+03 	 0.0 	 0.0
# protein_serine/threonine_kinase_activator_activity 	 5.06e+03 	 0.15 	 0.09
# nucleosome_binding 	 5.06e+03 	 0.15 	 0.09
# ATP-dependent_protein_folding_chaperone 	 5.06e+03 	 0.0 	 0.0
# RNA_polymerase_II_general_transcription_initiation_factor_activity 	 5.06e+03 	 0.0 	 0.0
# RNA_exonuclease_activity 	 5.06e+03 	 0.0 	 0.0
# RNA_polymerase_core_enzyme_binding 	 5.06e+03 	 0.0 	 0.0
# demethylase_activity 	 5.06e+03 	 0.0 	 0.0
# NADH_dehydrogenase_(ubiquinone)_activity 	 5.06e+03 	 0.0 	 0.0
# transition_metal_ion_transmembrane_transporter_activity 	 2.75e+02 	 0.0 	 0.0
# NADH_dehydrogenase_(quinone)_activity 	 5.06e+03 	 0.0 	 0.0
# steroid_binding 	 3.97e+03 	 1.21 	 0.74
# transmembrane_signaling_receptor_activity 	 7.74e+02 	 9.1 	 5.57
# thiolester_hydrolase_activity 	 3.32e+03 	 0.61 	 0.37
# translation_regulator_activity 	 5.06e+03 	 0.76 	 0.46
# hydrolase_activity,_acting_on_carbon-nitrogen_(but_not_peptide)_bonds,_in_linear_amides 	 3.63e+03 	 0.91 	 0.56
# translation_regulator_activity,_nucleic_acid_binding 	 5.06e+03 	 0.46 	 0.28
# protein_kinase_inhibitor_activity 	 5.06e+03 	 0.91 	 0.56
# DNA_binding 	 1.36e+02 	 21.7 	 13.27
# unfolded_protein_binding 	 5.06e+03 	 0.46 	 0.28
# acyltransferase_activity 	 3.37e+03 	 4.7 	 2.88
# acetylglucosaminyltransferase_activity 	 5.85e+02 	 0.61 	 0.37
# protein_serine/threonine/tyrosine_kinase_activity 	 5.06e+03 	 0.61 	 0.37
# virus_receptor_activity 	 5.06e+03 	 0.91 	 0.56
# amide_binding 	 3.81e+03 	 3.95 	 2.41
# exogenous_protein_binding 	 5.06e+03 	 0.91 	 0.56
# alpha-tubulin_binding 	 2.47e+03 	 0.61 	 0.37
# transcription_corepressor_binding 	 3.32e+03 	 0.61 	 0.37
# protein_tyrosine_kinase_binding 	 5.06e+03 	 1.37 	 0.83
# oxidoreductase_activity,_acting_on_NAD(P)H 	 3.22e+03 	 0.3 	 0.19
# endopeptidase_activity 	 3.59e+03 	 2.73 	 1.67
# translation_factor_activity,_RNA_binding 	 5.06e+03 	 0.3 	 0.19
# cytokine_receptor_binding 	 4.02e+03 	 1.52 	 0.93
# ubiquitin-like_protein_ligase_activity 	 1.61e+03 	 2.12 	 1.3
# monoatomic_anion_transmembrane_transporter_activity 	 2.97e+03 	 1.52 	 0.93
# proton_transmembrane_transporter_activity 	 3.07e+02 	 1.52 	 0.93
# hydrolase_activity,_acting_on_carbon-nitrogen_(but_not_peptide)_bonds 	 1.98e+03 	 1.52 	 0.93
# kinase_regulator_activity 	 4.30e+03 	 2.73 	 1.67
# ABC-type_transporter_activity 	 5.06e+03 	 0.61 	 0.37
# ligase_activity,_forming_carbon-nitrogen_bonds 	 1.54e+03 	 0.61 	 0.37
# intramolecular_oxidoreductase_activity 	 1.54e+03 	 0.61 	 0.37
# alcohol_binding 	 5.06e+03 	 1.06 	 0.65
# sulfur_compound_binding 	 3.59e+03 	 2.73 	 1.67
# monoatomic_anion_channel_activity 	 2.51e+03 	 1.06 	 0.65
# transcription_coregulator_activity 	 1.69e+03 	 3.19 	 1.95
# cytokine_receptor_activity 	 3.91e+03 	 1.06 	 0.65
# protein_phosphatase_regulator_activity 	 2.51e+03 	 1.06 	 0.65
# pyrophosphatase_activity 	 3.64e+03 	 6.98 	 4.27
# vitamin_B6_binding 	 5.06e+03 	 0.15 	 0.09
# oxidoreductase_activity,_acting_on_peroxide_as_acceptor 	 2.84e+03 	 0.15 	 0.09
# RNA_polymerase_binding 	 5.06e+03 	 0.15 	 0.09
# DNA_nuclease_activity 	 5.06e+03 	 0.15 	 0.09
# basal_RNA_polymerase_II_transcription_machinery_binding 	 5.06e+03 	 0.15 	 0.09
# basal_transcription_machinery_binding 	 5.06e+03 	 0.15 	 0.09
# growth_factor_activity 	 5.06e+03 	 1.67 	 1.02
# peptidase_inhibitor_activity 	 1.33e+03 	 0.91 	 0.56
# copper_ion_binding 	 3.62e+03 	 0.76 	 0.46
# heparin_binding 	 1.96e+03 	 1.82 	 1.11
# protein_homodimerization_activity 	 2.62e+03 	 6.53 	 3.99
# nucleocytoplasmic_carrier_activity 	 5.06e+03 	 0.0 	 0.0
# miRNA_binding 	 5.06e+03 	 0.0 	 0.0
# snoRNA_binding 	 5.06e+03 	 0.0 	 0.0
# macromolecule_transmembrane_transporter_activity 	 1.92e+03 	 0.0 	 0.0
# hydrolase_activity,_acting_on_acid_anhydrides,_in_phosphorus-containing_anhydrides 	 3.64e+03 	 6.98 	 4.27
# hydrolase_activity,_acting_on_acid_anhydrides 	 3.64e+03 	 6.98 	 4.27
# organophosphate_ester_transmembrane_transporter_activity 	 1.92e+03 	 0.0 	 0.0
# tRNA_methyltransferase_activity 	 5.06e+03 	 0.0 	 0.0
# serine-type_peptidase_activity 	 5.06e+03 	 1.06 	 0.65
# RNA_polymerase_II_complex_binding 	 5.06e+03 	 0.0 	 0.0
# ubiquitin-protein_transferase_regulator_activity 	 5.06e+03 	 0.46 	 0.28
# zinc_ion_binding 	 4.12e+03 	 7.44 	 4.55
# oxidoreductase_activity,_acting_on_the_CH-CH_group_of_donors,_NAD_or_NADP_as_acceptor 	 5.06e+03 	 0.46 	 0.28
# 14-3-3_protein_binding 	 1.48e+03 	 0.46 	 0.28
# tRNA_binding 	 2.67e+03 	 0.3 	 0.19
# RNA_helicase_activity 	 3.22e+03 	 0.3 	 0.19
# RNA_endonuclease_activity 	 5.06e+03 	 0.3 	 0.19
# ATP-dependent_activity,_acting_on_RNA 	 3.22e+03 	 0.3 	 0.19
# molecular_function_inhibitor_activity 	 1.45e+03 	 5.01 	 3.06
# ribonucleoside_triphosphate_phosphatase_activity 	 2.71e+03 	 6.37 	 3.9
# phosphotransferase_activity,_phosphate_group_as_acceptor 	 5.06e+03 	 0.46 	 0.28
# palmitoyltransferase_activity 	 5.06e+03 	 0.46 	 0.28
# SNAP_receptor_activity 	 3.44e+03 	 0.46 	 0.28
# receptor_tyrosine_kinase_binding 	 3.83e+03 	 0.91 	 0.56
# kinase_inhibitor_activity 	 5.06e+03 	 0.91 	 0.56
# kinase_activator_activity 	 2.41e+03 	 1.52 	 0.93
# ubiquitin_protein_ligase_activity 	 1.61e+03 	 2.12 	 1.3
# protein_kinase_regulator_activity 	 2.78e+03 	 2.28 	 1.39
# frizzled_binding 	 3.44e+03 	 0.46 	 0.28
# lipid_kinase_activity 	 5.06e+03 	 0.46 	 0.28
# small_molecule_sensor_activity 	 5.06e+03 	 0.46 	 0.28
# sodium_ion_transmembrane_transporter_activity 	 4.07e+03 	 1.52 	 0.93
# primary_active_transmembrane_transporter_activity 	 1.96e+03 	 0.91 	 0.56
# beta-tubulin_binding 	 1.48e+03 	 0.46 	 0.28
# ligase_activity,_forming_carbon-sulfur_bonds 	 5.06e+03 	 0.46 	 0.28
# transferase_activity 	 5.06e+03 	 19.42 	 11.87
# ubiquitin_binding 	 3.44e+03 	 0.46 	 0.28
# N-methyltransferase_activity 	 1.48e+03 	 0.46 	 0.28
# nucleobase-containing_compound_kinase_activity 	 5.06e+03 	 0.46 	 0.28
# active_transmembrane_transporter_activity 	 4.32e+03 	 2.88 	 1.76
# G_protein_activity 	 5.06e+03 	 0.46 	 0.28
# cysteine-type_endopeptidase_regulator_activity_involved_in_apoptotic_process 	 5.06e+03 	 0.46 	 0.28
# intramembrane_lipid_transporter_activity 	 5.06e+03 	 0.46 	 0.28
# signal_sequence_binding 	 2.84e+03 	 0.15 	 0.09
# oxidoreductase_activity,_acting_on_the_aldehyde_or_oxo_group_of_donors 	 7.89e+02 	 0.15 	 0.09
# cis-trans_isomerase_activity 	 5.06e+03 	 0.15 	 0.09
# cyclin-dependent_protein_serine/threonine_kinase_regulator_activity 	 7.89e+02 	 0.15 	 0.09
# carbohydrate_derivative_transmembrane_transporter_activity 	 5.06e+03 	 0.15 	 0.09
# metalloendopeptidase_activity 	 3.91e+03 	 1.06 	 0.65
# nucleobase-containing_compound_transmembrane_transporter_activity 	 5.06e+03 	 0.15 	 0.09
# translation_initiation_factor_activity 	 5.06e+03 	 0.15 	 0.09
# pentosyltransferase_activity 	 5.06e+03 	 0.15 	 0.09
# general_transcription_initiation_factor_binding 	 5.06e+03 	 0.15 	 0.09
# quaternary_ammonium_group_binding 	 3.63e+02 	 0.15 	 0.09
# serine_hydrolase_activity 	 5.06e+03 	 1.21 	 0.74
# peptidase_activity 	 4.43e+03 	 4.4 	 2.69
# hydrolase_activity 	 3.59e+03 	 20.33 	 12.43
# pyridoxal_phosphate_binding 	 5.06e+03 	 0.15 	 0.09
# histone_deacetylase_binding 	 1.58e+03 	 0.61 	 0.37
# transition_metal_ion_binding 	 5.06e+03 	 9.56 	 5.84
# nuclear_receptor_coactivator_activity 	 1.54e+03 	 0.61 	 0.37
# RNA_polymerase_II-specific_DNA-binding_transcription_factor_binding 	 2.93e+03 	 3.19 	 1.95
# ubiquitin-like_protein_peptidase_activity 	 2.11e+03 	 0.76 	 0.46
# glycosaminoglycan_binding 	 3.47e+03 	 2.28 	 1.39
# oxidoreductase_activity,_acting_on_the_CH-CH_group_of_donors 	 5.06e+03 	 0.61 	 0.37
# immune_receptor_activity 	 5.06e+03 	 1.37 	 0.83
# promoter-specific_chromatin_binding 	 3.32e+03 	 0.61 	 0.37
# heterocyclic_compound_binding 	 1.02e+03 	 46.13 	 28.2
# p53_binding 	 5.06e+03 	 0.3 	 0.19
# metal_cluster_binding 	 2.67e+03 	 0.3 	 0.19
# iron-sulfur_cluster_binding 	 2.67e+03 	 0.3 	 0.19
# transferase_activity,_transferring_sulphur-containing_groups 	 1.89e+03 	 0.3 	 0.19
# carbohydrate_binding 	 3.32e+03 	 1.82 	 1.11
# lipid_transporter_activity 	 1.44e+03 	 1.06 	 0.65
# serine-type_endopeptidase_activity 	 3.80e+03 	 1.06 	 0.65
# monocarboxylic_acid_binding 	 5.06e+03 	 0.76 	 0.46
# hydrolase_activity,_acting_on_ester_bonds 	 4.06e+03 	 6.53 	 3.99
# metallopeptidase_activity 	 4.11e+03 	 1.67 	 1.02
# cysteine-type_peptidase_activity 	 5.06e+03 	 1.21 	 0.74
# dioxygenase_activity 	 3.44e+03 	 0.46 	 0.28
# organic_acid_binding 	 1.68e+03 	 1.37 	 0.83
# N-acyltransferase_activity 	 4.49e+02 	 0.91 	 0.56
# organic_cyclic_compound_binding 	 9.31e+02 	 46.89 	 28.66
# exopeptidase_activity 	 3.83e+03 	 0.91 	 0.56
# phosphatase_regulator_activity 	 3.80e+03 	 1.06 	 0.65
# solute:monoatomic_cation_symporter_activity 	 1.38e+03 	 1.06 	 0.65
# translation_repressor_activity 	 2.67e+03 	 0.3 	 0.19
# secondary_active_transmembrane_transporter_activity 	 5.06e+03 	 1.82 	 1.11
# 5'-3'_RNA_polymerase_activity 	 5.06e+03 	 0.3 	 0.19
# RNA_polymerase_activity 	 5.06e+03 	 0.3 	 0.19
# G_protein-coupled_peptide_receptor_activity 	 2.62e+03 	 0.76 	 0.46
# peptide_receptor_activity 	 2.62e+03 	 0.76 	 0.46
# protein-disulfide_reductase_activity 	 5.06e+03 	 0.3 	 0.19
# protein_kinase_activator_activity 	 1.09e+03 	 1.21 	 0.74
# ubiquitin_conjugating_enzyme_activity 	 5.06e+03 	 0.3 	 0.19
# signaling_receptor_regulator_activity 	 2.75e+03 	 4.1 	 2.5
# GTPase_binding 	 1.58e+02 	 2.73 	 1.67
# heme_binding 	 1.70e+03 	 1.21 	 0.74
# nucleotidyltransferase_activity 	 5.07e+02 	 1.37 	 0.83
# carboxylic_ester_hydrolase_activity 	 2.32e+03 	 1.37 	 0.83
# integrin_binding 	 5.06e+03 	 1.37 	 0.83
# FAD_binding 	 7.89e+02 	 0.15 	 0.09
# DNA_endonuclease_activity 	 5.06e+03 	 0.15 	 0.09
# aminopeptidase_activity 	 2.84e+03 	 0.15 	 0.09
# DNA_polymerase_activity 	 5.06e+03 	 0.15 	 0.09
# ligase_activity,_forming_carbon-oxygen_bonds 	 5.06e+03 	 0.15 	 0.09
# aminoacyl-tRNA_ligase_activity 	 5.06e+03 	 0.15 	 0.09
# 4_iron,_4_sulfur_cluster_binding 	 5.06e+03 	 0.15 	 0.09
# regulatory_RNA_binding 	 5.06e+03 	 0.15 	 0.09
# peptidyl-prolyl_cis-trans_isomerase_activity 	 5.06e+03 	 0.15 	 0.09
# neutral_L-amino_acid_transmembrane_transporter_activity 	 5.06e+03 	 0.15 	 0.09
# ligase_activity 	 3.07e+02 	 1.52 	 0.93
# protein_phosphatase_inhibitor_activity 	 5.06e+03 	 0.46 	 0.28
# oxidoreductase_activity,_acting_on_paired_donors,_with_incorporation_or_reduction_of_molecular_oxygen 	 3.01e+03 	 1.21 	 0.74
# tumor_necrosis_factor_receptor_superfamily_binding 	 1.48e+03 	 0.46 	 0.28
# hexosyltransferase_activity 	 4.78e+02 	 1.67 	 1.02
# phosphatase_inhibitor_activity 	 5.06e+03 	 0.46 	 0.28
# protein_kinase_A_binding 	 4.61e+02 	 0.46 	 0.28
# carboxylic_acid_binding 	 1.68e+03 	 1.37 	 0.83
# NAD_binding 	 5.06e+03 	 0.46 	 0.28
# NADP_binding 	 3.44e+03 	 0.46 	 0.28
# signaling_receptor_activator_activity 	 1.80e+03 	 3.79 	 2.32
# O-acyltransferase_activity 	 5.06e+03 	 0.46 	 0.28
# monocarboxylic_acid_transmembrane_transporter_activity 	 5.06e+03 	 0.3 	 0.19
# transferase_activity,_transferring_alkyl_or_aryl_(other_than_methyl)_groups 	 5.06e+03 	 0.3 	 0.19
# histone_methyltransferase_activity 	 5.06e+03 	 0.3 	 0.19
# L-amino_acid_transmembrane_transporter_activity 	 5.06e+03 	 0.3 	 0.19
# ATP-dependent_activity 	 4.43e+03 	 4.25 	 2.6
# glycosyltransferase_activity 	 1.28e+03 	 2.28 	 1.39
# GDP_binding 	 5.06e+03 	 0.61 	 0.37
# double-stranded_RNA_binding 	 5.06e+03 	 0.61 	 0.37
# G_protein-coupled_receptor_binding 	 9.53e+01 	 2.12 	 1.3
# amino_acid_transmembrane_transporter_activity 	 5.06e+03 	 0.46 	 0.28
# single-stranded_RNA_binding 	 5.06e+03 	 0.76 	 0.46
# hydrolase_activity,_hydrolyzing_O-glycosyl_compounds 	 5.06e+03 	 0.61 	 0.37
# acetyltransferase_activity 	 1.54e+03 	 0.61 	 0.37
# monooxygenase_activity 	 5.06e+03 	 0.91 	 0.56
# ubiquitin-like_protein_binding 	 5.06e+03 	 0.76 	 0.46
# chromatin_DNA_binding 	 2.11e+03 	 0.76 	 0.46
# antiporter_activity 	 5.06e+03 	 0.76 	 0.46
# deubiquitinase_activity 	 2.11e+03 	 0.76 	 0.46
# cysteine-type_endopeptidase_activity 	 3.73e+03 	 0.76 	 0.46
# single-stranded_DNA_binding 	 3.62e+03 	 0.76 	 0.46
# receptor_ligand_activity 	 1.80e+03 	 3.79 	 2.32
# cytokine_binding 	 3.01e+03 	 1.21 	 0.74
# protease_binding 	 1.70e+03 	 1.21 	 0.74
# UDP-glycosyltransferase_activity 	 4.78e+02 	 1.21 	 0.74
# symporter_activity 	 8.39e+02 	 1.21 	 0.74
# tetrapyrrole_binding 	 1.70e+03 	 1.21 	 0.74
# iron_ion_binding 	 3.80e+03 	 1.06 	 0.65
# carboxylic_acid_transmembrane_transporter_activity 	 2.51e+03 	 1.06 	 0.65
# molecular_transducer_activity 	 1.02e+03 	 11.99 	 7.33
# signaling_receptor_activity 	 1.02e+03 	 11.99 	 7.33
# extracellular_matrix_structural_constituent 	 5.06e+03 	 1.37 	 0.83
# catalytic_activity 	 4.18e+03 	 45.22 	 27.64
# transcription_corepressor_activity 	 3.93e+03 	 1.37 	 0.83
# magnesium_ion_binding 	 5.06e+03 	 1.82 	 1.11
# acyltransferase_activity,_transferring_groups_other_than_amino-acyl_groups 	 4.10e+03 	 1.82 	 1.11
# organic_anion_transmembrane_transporter_activity 	 1.38e+03 	 1.67 	 1.02
# active_monoatomic_ion_transmembrane_transporter_activity 	 3.24e+03 	 1.97 	 1.21
# small_GTPase_binding 	 7.25e+01 	 2.28 	 1.39
# hydro-lyase_activity 	 5.06e+03 	 0.46 	 0.28
# metalloexopeptidase_activity 	 2.21e+03 	 0.46 	 0.28
# manganese_ion_binding 	 3.44e+03 	 0.46 	 0.28
# sulfur_compound_transmembrane_transporter_activity 	 2.67e+03 	 0.3 	 0.19
# peptide_N-acetyltransferase_activity 	 2.67e+03 	 0.3 	 0.19
# flavin_adenine_dinucleotide_binding 	 2.47e+03 	 0.61 	 0.37
# phospholipid_transporter_activity 	 3.44e+03 	 0.46 	 0.28
# ATPase-coupled_transmembrane_transporter_activity 	 1.77e+03 	 0.76 	 0.46
# neurotransmitter_receptor_activity 	 4.56e+02 	 0.76 	 0.46
# amino_acid_binding 	 5.06e+03 	 0.46 	 0.28
# antioxidant_activity 	 5.06e+03 	 0.61 	 0.37
# oxidoreductase_activity,_acting_on_a_sulfur_group_of_donors 	 5.06e+03 	 0.3 	 0.19
# methylation-dependent_protein_binding 	 3.32e+03 	 0.61 	 0.37
# sterol_binding 	 3.44e+03 	 0.46 	 0.28
# lysine_N-methyltransferase_activity 	 1.48e+03 	 0.46 	 0.28
# nuclear_thyroid_hormone_receptor_binding 	 5.06e+03 	 0.15 	 0.09
# protein-lysine_N-methyltransferase_activity 	 1.48e+03 	 0.46 	 0.28
# ubiquitin-like_protein_conjugating_enzyme_activity 	 3.22e+03 	 0.3 	 0.19
# hydrolase_activity,_hydrolyzing_N-glycosyl_compounds 	 3.22e+03 	 0.3 	 0.19
# N-acetyltransferase_activity 	 1.48e+03 	 0.46 	 0.28
# Hsp70_protein_binding 	 5.06e+03 	 0.3 	 0.19
# cysteine-type_deubiquitinase_activity 	 2.11e+03 	 0.76 	 0.46
# methylated_histone_binding 	 5.06e+03 	 0.46 	 0.28
# carbon-oxygen_lyase_activity 	 5.06e+03 	 0.46 	 0.28
# cyclin-dependent_protein_serine/threonine_kinase_activity 	 2.84e+03 	 0.15 	 0.09
# DNA-directed_5'-3'_RNA_polymerase_activity 	 5.06e+03 	 0.15 	 0.09
# cyclin-dependent_protein_kinase_activity 	 2.84e+03 	 0.15 	 0.09
# protein_serine/threonine_kinase_inhibitor_activity 	 3.63e+02 	 0.15 	 0.09
# endonuclease_activity,_active_with_either_ribo-_or_deoxyribonucleic_acids_and_producing_5'-phosphomonoesters 	 2.67e+03 	 0.3 	 0.19
# core_promoter_sequence-specific_DNA_binding 	 5.06e+03 	 0.3 	 0.19
# enzyme-substrate_adaptor_activity 	 5.06e+03 	 0.3 	 0.19
# ATPase_regulator_activity 	 5.06e+03 	 0.3 	 0.19
# protein_methyltransferase_activity 	 5.06e+03 	 0.61 	 0.37
# protein-folding_chaperone_binding 	 5.06e+03 	 1.06 	 0.65
# peptide-lysine-N-acetyltransferase_activity 	 2.67e+03 	 0.3 	 0.19
# ubiquitin_ligase-substrate_adaptor_activity 	 5.06e+03 	 0.3 	 0.19
# protein_tyrosine/serine/threonine_phosphatase_activity 	 3.22e+03 	 0.3 	 0.19
# cholesterol_binding 	 1.89e+03 	 0.3 	 0.19
# ATPase-coupled_monoatomic_cation_transmembrane_transporter_activity 	 1.05e+03 	 0.3 	 0.19
# sulfotransferase_activity 	 1.89e+03 	 0.3 	 0.19
# telomeric_DNA_binding 	 5.06e+03 	 0.3 	 0.19
# RNA_endonuclease_activity,_producing_5'-phosphomonoesters 	 2.67e+03 	 0.3 	 0.19
# disulfide_oxidoreductase_activity 	 5.06e+03 	 0.3 	 0.19
# translation_initiation_factor_binding 	 5.06e+03 	 0.15 	 0.09
# protein_carrier_chaperone 	 2.84e+03 	 0.15 	 0.09
# organic_acid_transmembrane_transporter_activity 	 1.70e+03 	 1.21 	 0.74
# phosphatidylinositol_phosphate_phosphatase_activity 	 5.06e+03 	 0.15 	 0.09
# histone_acetyltransferase_activity 	 2.67e+03 	 0.3 	 0.19
# Hsp90_protein_binding 	 2.67e+03 	 0.3 	 0.19
# carbon-carbon_lyase_activity 	 3.22e+03 	 0.3 	 0.19
# hydrolase_activity,_acting_on_glycosyl_bonds 	 3.91e+03 	 1.06 	 0.65
# histone_H3_methyltransferase_activity 	 2.67e+03 	 0.3 	 0.19
# isomerase_activity 	 8.39e+02 	 1.21 	 0.74
# DNA_secondary_structure_binding 	 5.06e+03 	 0.15 	 0.09
# deacetylase_activity 	 5.06e+03 	 0.15 	 0.09
# peptidase_regulator_activity 	 3.12e+03 	 1.82 	 1.11
# transcription_coactivator_activity 	 6.53e+02 	 2.12 	 1.3
# enzyme_inhibitor_activity 	 1.69e+03 	 3.19 	 1.95
# chromatin_binding 	 2.72e+03 	 4.7 	 2.88
